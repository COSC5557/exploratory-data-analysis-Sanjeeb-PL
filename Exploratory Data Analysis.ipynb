# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv(r"C:/Users/shumagai/Desktop/PML Spring 2024/wine_quality/winequality-white.csv")
df = pd.read_csv("wine_quality/winequality-white.csv", sep=';')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.00              0.27         0.36           20.70       0.04
# 1              6.30              0.30         0.34            1.60       0.05
# 2              8.10              0.28         0.40            6.90       0.05
# 3              7.20              0.23         0.32            8.50       0.06
# 4              7.20              0.23         0.32            8.50       0.06
# ...             ...               ...          ...             ...        ...
# 4893           6.20              0.21         0.29            1.60       0.04
# 4894           6.60              0.32         0.36            8.00       0.05
# 4895           6.50              0.24         0.19            1.20       0.04
# 4896           5.50              0.29         0.30            1.10       0.02
# 4897           6.00              0.21         0.38            0.80       0.02
#
# ...

# %%
# to change the float to two decimal places following code is used
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.00              0.27         0.36           20.70       0.04
# 1              6.30              0.30         0.34            1.60       0.05
# 2              8.10              0.28         0.40            6.90       0.05
# 3              7.20              0.23         0.32            8.50       0.06
# 4              7.20              0.23         0.32            8.50       0.06
# ...             ...               ...          ...             ...        ...
# 4893           6.20              0.21         0.29            1.60       0.04
# 4894           6.60              0.32         0.36            8.00       0.05
# 4895           6.50              0.24         0.19            1.20       0.04
# 4896           5.50              0.29         0.30            1.10       0.02
# 4897           6.00              0.21         0.38            0.80       0.02
#
# ...

# %%
# prints the high level information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
# gives additional statistical information
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        4898.00           4898.00      4898.00         4898.00
# mean            6.85              0.28         0.33            6.39
# std             0.84              0.10         0.12            5.07
# min             3.80              0.08         0.00            0.60
# 25%             6.30              0.21         0.27            1.70
# 50%             6.80              0.26         0.32            5.20
# 75%             7.30              0.32         0.39            9.90
# max            14.20              1.10         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count    4898.00              4898.00               4898.00  4898.00 4898.00
# mean        0.05                35.31                138.36     0.99    3.19
# std         0.02                17.01                 42.50     0.00    0.15
# ...

# %%
# to check the total missing data on each features
# zero indicates there is no missing data values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.nunique()
# shows how many unquiue value in each column
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
df.sort_values(by="density",ascending= False).head(10)
# to sort values based on certain fearures, high values will be printed
# this will help to see, for eg top 10 data and their corresponding features
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2781           7.80              0.96         0.60           65.80       0.07
# 1653           7.90              0.33         0.28           31.60       0.05
# 1663           7.90              0.33         0.28           31.60       0.05
# 3619           6.80              0.45         0.28           26.05       0.03
# 3623           6.80              0.45         0.28           26.05       0.03
# 2334           7.50              0.23         0.35           17.80       0.06
# 1608           6.90              0.27         0.49           23.50       0.06
# 3420           7.60              0.28         0.49           20.15       0.06
# 2250           9.20              0.34         0.54           17.30       0.06
# 1958           7.40              0.32         0.55           16.60       0.06
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# ...

# %%
df.corr()
# to see the correlation between features
# this helps to see how one parameters has effects on others
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity                  1.00             -0.02         0.29
# volatile acidity              -0.02              1.00        -0.15
# citric acid                    0.29             -0.15         1.00
# residual sugar                 0.09              0.06         0.09
# chlorides                      0.02              0.07         0.11
# free sulfur dioxide           -0.05             -0.10         0.09
# total sulfur dioxide           0.09              0.09         0.12
# density                        0.27              0.03         0.15
# pH                            -0.43             -0.03        -0.16
# sulphates                     -0.02             -0.04         0.06
# alcohol                       -0.12              0.07        -0.08
# quality                       -0.11             -0.19        -0.01
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(df.corr(), annot= True)
plt.rcParams["figure.figsize"]=(20,7)
plt.show()
# to visualize the correlation data in plot

# %%
df2 = df.groupby('quality')[['residual sugar','fixed acidity', 'citric acid',
       'chlorides', 'density','pH', 'alcohol']].mean().sort_values(by='density', ascending= False)
df3 = df2.transpose()
df3.plot()
# Out:
# <Axes: >

# %%
df.boxplot()
# boxplot help to visualize outliers
# deleting those outliers are important to improve the performance of model
# Out:
# <Axes: >

# %%
df.select_dtypes(include = 'number')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.00              0.27         0.36           20.70       0.04
# 1              6.30              0.30         0.34            1.60       0.05
# 2              8.10              0.28         0.40            6.90       0.05
# 3              7.20              0.23         0.32            8.50       0.06
# 4              7.20              0.23         0.32            8.50       0.06
# ...             ...               ...          ...             ...        ...
# 4893           6.20              0.21         0.29            1.60       0.04
# 4894           6.60              0.32         0.36            8.00       0.05
# 4895           6.50              0.24         0.19            1.20       0.04
# 4896           5.50              0.29         0.30            1.10       0.02
# 4897           6.00              0.21         0.38            0.80       0.02
#
# ...

# %%
print(df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#df4 = df.groupby('quality')[['residual sugar', 'alcohol']].mean().sort_values(by='alcohol', ascending= False)
df4 = df.groupby('fixed acidity')[['density', 'fixed acidity']].mean()
print(df4)
#df4.plot()
plt.plot(df4['fixed acidity'],df4['density'], marker = '*', linestyle= '-')
plt.xlabel('fixed acidity')
plt.ylabel('Desnsity')
plt.title('Plot of fixed acidity vs Density')
plt.grid(True)
plt.show()
# Out:
#                density  fixed acidity
# fixed acidity
# 3.80              0.99           3.80
# 3.90              0.99           3.90
# 4.20              0.99           4.20
# 4.40              0.99           4.40
# 4.50              0.99           4.50
# ...                ...            ...
# 10.20             1.00          10.20
# 10.30             1.00          10.30
# 10.70             1.00          10.70
# 11.80             1.00          11.80
# 14.20             0.99          14.20
#
# [68 rows x 2 columns]

# %%
df.hist(bins=50, figsize= (20,15))
plt.show()
